# %% [markdown]
# # 04 - Normalizar imagenes con Rasterio por subproceso
#
# Ejecutar desde el kernel de ArcGIS Pro. Este notebook usa `arcpy` para leer footprints y delega `rasterio` al ambiente:
#
# `C:\\Users\\esrlrivero_adm\\AppData\\Local\\ESRI\\conda\\envs\\geo-raster-py311`

# %%
from pathlib import Path
import importlib
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'core').exists():
    for candidate in [Path.cwd().parent, Path.cwd().parent.parent]:
        if (candidate / 'core').exists():
            PROJECT_ROOT = candidate
            break

if not (PROJECT_ROOT / 'core').exists():
    raise FileNotFoundError('No se encontro el folder core. Ejecuta el notebook desde la raiz del proyecto o desde flujo_geosupport_etapas.')

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

FLOW_DIR = PROJECT_ROOT / 'flujo_geosupport_etapas'

import core.rasterio_subprocess as rasterio_subprocess
rasterio_subprocess = importlib.reload(rasterio_subprocess)
from core.rasterio_subprocess import DEFAULT_RASTERIO_ENV_PATH, run_stage_04_rasterio_subprocess

print('Proyecto raiz:', PROJECT_ROOT)
print('Folder flujo:', FLOW_DIR)
print('Ambiente rasterio:', DEFAULT_RASTERIO_ENV_PATH)
# Out:
# Proyecto raiz: c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport
# Folder flujo: c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas
# Ambiente rasterio: C:\Users\esrlrivero_adm\AppData\Local\ESRI\conda\envs\geo-raster-py311

# %%
LOAD_RESULTS_CSV = FLOW_DIR / 'outputs' / 'etapa_02_carga_datastore_mosaico' / '02_load_results.csv'
LOAD_INPUT_ATTRIBUTES_CSV = FLOW_DIR / 'outputs' / 'etapa_02_carga_datastore_mosaico' / '01_load_input_with_attributes.csv'

PATH_FC_FOOTPRINTS = r"\\amssclgis08.ams.gmams.cl\CL_MLP_PAO\02_FGDB\CL_MLP_PAO_v1.gdb\CL_MLP_PAO_06_COMPLEMENTOS\CL_MLP_PAO_Indice_Vuelos_PAO_IMGS_PO"
FOOTPRINT_NAME_FIELD = 'Name'

RASTERIO_ENV_PATH = DEFAULT_RASTERIO_ENV_PATH

PROCESS_ONLY_SUCCESSFUL_LOADS = True
LIMIT_ROWS = None
REPLACE_ORIGINALS = True
CREATE_BACKUP_BEFORE_REPLACE = False
BUILD_PYRAMIDS_AFTER_REPLACE = False
BACKUP_SUFFIX = '.bak_original_before_rasterio'

OUTPUT_DIR = FLOW_DIR / 'outputs' / 'etapa_04_normalizar_imagenes_rasterio'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print('CSV resultados etapa 2:', LOAD_RESULTS_CSV)
print('CSV input atributos etapa 2:', LOAD_INPUT_ATTRIBUTES_CSV)
print('Feature footprints:', PATH_FC_FOOTPRINTS)
print('Salida:', OUTPUT_DIR)
print('Ambiente rasterio:', RASTERIO_ENV_PATH)
print('REPLACE_ORIGINALS:', REPLACE_ORIGINALS)
# Out:
# CSV resultados etapa 2: c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_02_carga_datastore_mosaico\02_load_results.csv
# CSV input atributos etapa 2: c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_02_carga_datastore_mosaico\01_load_input_with_attributes.csv
# Feature footprints: \\amssclgis08.ams.gmams.cl\CL_MLP_PAO\02_FGDB\CL_MLP_PAO_v1.gdb\CL_MLP_PAO_06_COMPLEMENTOS\CL_MLP_PAO_Indice_Vuelos_PAO_IMGS_PO
# Salida: c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio
# Ambiente rasterio: C:\Users\esrlrivero_adm\AppData\Local\ESRI\conda\envs\geo-raster-py311
# REPLACE_ORIGINALS: True

# %%
completed = run_stage_04_rasterio_subprocess(
    load_results_csv=LOAD_RESULTS_CSV,
    load_input_attributes_csv=LOAD_INPUT_ATTRIBUTES_CSV,
    footprints_feature_class=PATH_FC_FOOTPRINTS,
    footprint_name_field=FOOTPRINT_NAME_FIELD,
    output_dir=OUTPUT_DIR,
    env_path=RASTERIO_ENV_PATH,
    process_only_successful_loads=PROCESS_ONLY_SUCCESSFUL_LOADS,
    limit_rows=LIMIT_ROWS,
    replace_originals=REPLACE_ORIGINALS,
    create_backup_before_replace=CREATE_BACKUP_BEFORE_REPLACE,
    build_pyramids_after_replace=BUILD_PYRAMIDS_AFTER_REPLACE,
    backup_suffix=BACKUP_SUFFIX,
)

completed.returncode
# Out:
# Advertencia: nombres duplicados en footprints: ['CL_MLP_PAO_IF_Ortho_26_04_17_EB3', 'CL_MLP_PAO_IF_Ortho_26_04_18_Helipuerto', 'CL_MLP_PAO_IF_Ortho_26_04_22_EB3', 'CL_MLP_PAO_IF_Ortho_26_04_23_TORRES_E35_A_E48', 'CL_MLP_PAO_IF_Ortho_26_04_24_Patio-19B-y-Armado', 'CL_MLP_PAO_IF_Ortho_26_04_25_EBD', 'CL_MLP_PAO_IF_Ortho_26_04_25_Pozos_PRP']
# Footprints faltantes omitidos: 1. Revision: c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\00_missing_footprints_for_rasterio.csv
#
# Traceback (most recent call last):
#
#   File "c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\core\rasterio_normalize_worker.py", line 19, in <module>
#
#     csv.field_size_limit(sys.maxsize)
#
# OverflowError: Python int too large to convert to C long
#
#
# ERROR conda.cli.main_run:execute(49): `conda run python c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\core\rasterio_normalize_worker.py --manifest c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\rasterio_manifest_20260622_153128.csv --summary-csv c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\00_summary.csv --results-csv c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\01_normalizacion_rasterio_resultados.csv --errors-csv c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\02_errors_review.csv --backup-suffix .bak_original_before_rasterio --replace-originals` failed. (See above for error)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1520\2465139628.py in <cell line: 1>()
# ----> 1 completed = run_stage_04_rasterio_subprocess(
#       2     load_results_csv=LOAD_RESULTS_CSV,
#       3     load_input_attributes_csv=LOAD_INPUT_ATTRIBUTES_CSV,
#       4     footprints_feature_class=PATH_FC_FOOTPRINTS,
#       5     footprint_name_field=FOOTPRINT_NAME_FIELD,
#
# c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\core\rasterio_subprocess.py in run_stage_04_rasterio_subprocess(load_results_csv, load_input_attributes_csv, footprints_feature_class, footprint_name_field, output_dir, env_name, env_path, process_only_successful_loads, limit_rows, replace_originals, create_backup_before_replace, build_pyramids_after_replace, backup_suffix)
#     328
#     329     if completed.returncode != 0:
# --> 330         raise RuntimeError(
#     331             "El subproceso rasterio termino con codigo {}.\nSTDOUT:\n{}\nSTDERR:\n{}".format(
#     332                 completed.returncode,
#
# RuntimeError: El subproceso rasterio termino con codigo 1.
# STDOUT:
#
# STDERR:
# Traceback (most recent call last):
#
#   File "c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\core\rasterio_normalize_worker.py", line 19, in <module>
#
#     csv.field_size_limit(sys.maxsize)
#
# OverflowError: Python int too large to convert to C long
#
#
# ERROR conda.cli.main_run:execute(49): `conda run python c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\core\rasterio_normalize_worker.py --manifest c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\rasterio_manifest_20260622_153128.csv --summary-csv c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\00_summary.csv --results-csv c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\01_normalizacion_rasterio_resultados.csv --errors-csv c:\Users\esrlrivero_adm\Documents\Geosupport\amsa-pao-geosupport\flujo_geosupport_etapas\outputs\etapa_04_normalizar_imagenes_rasterio\02_errors_review.csv --backup-suffix .bak_original_before_rasterio --replace-originals` failed. (See above for error)
